# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from ae_models_mlp import MLP, train_mlp, grid_search_mlp
#from ae_MLP import RNN

torch.manual_seed(1)

data = np.load("./data/ae_data.npz")

Str = data["Str"]
Xtr = torch.from_numpy(data["Xtr"]).type(torch.int)
Ytr = torch.from_numpy(data["Ytr"]).type(torch.float)

Ste = data["Ste"]
Xte = torch.from_numpy(data["Xte"]).type(torch.int)
Yte = torch.from_numpy(data["Yte"]).type(torch.float)

#print("Example data cases:")
#for i in range(10):
#    print("%d: (%s,%d)"%(i,Str[i],Ytr[i]))

# Set hyperparameters
batch_size = 64
learning_rate = 0.001
num_epochs = 100


#model = MLP()
#criterion = nn.MSELoss()
#optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


#model = LSTM()
#criterion = nn.MSELoss()
#optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


#model = Transformer()
# criterion = nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


torch.manual_seed(1)

data = np.load("./data/ae_data.npz")

Str = data["Str"]
Xtr = torch.from_numpy(data["Xtr"]).type(torch.int)
Ytr = torch.from_numpy(data["Ytr"]).type(torch.float)

Ste = data["Ste"]
Xte = torch.from_numpy(data["Xte"]).type(torch.int)
Yte = torch.from_numpy(data["Yte"]).type(torch.float)

# set random seed for reproducibility
np.random.seed(42)

# randomly shuffle the data indices
indices = np.arange(Xtr.shape[0])
np.random.shuffle(indices)

# define validation set size
val_size = 0.2  # 20% of training set

# split the shuffled data into training and validation sets
split = int(np.floor(Xtr.shape[0] * (1 - val_size)))
train_idx, val_idx = indices[:split], indices[split:]
Xtrain, Ytrain = Xtr[train_idx], Ytr[train_idx]
Xval, Yval = Xtr[val_idx], Ytr[val_idx]

# Define model and optimizer
model = MLP(input_dim=Xtrain.shape[1], hidden_dim=64, output_dim=1)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train model
#train_mlp(Xtrain, Ytrain, model, optimizer)

learning_rates = [0.1, 0.01, 0.001]
hidden_sizes = [64, 128, 256]
batch_sizes = [128, 256, 512, 1024]

grid_search_mlp(Xtrain, Ytrain, Xval, Yval, learning_rates, hidden_sizes, batch_sizes)
# Out:
# Epoch 0: Loss = 124367.140625
# Epoch 100: Loss = 10296.341796875
# Epoch 200: Loss = 717.1953735351562
# Epoch 300: Loss = 411.1199951171875
# Epoch 400: Loss = 497.37542724609375
# Epoch 500: Loss = 667.17724609375
# Epoch 600: Loss = 257.09228515625
# Epoch 700: Loss = 700.8143310546875
# Epoch 800: Loss = 607.422607421875
# Epoch 900: Loss = 610.9010009765625
# lr=0.1, hidden_size=64, batch_size=128, test_loss=1070.1268310546875
# Epoch 0: Loss = 121829.90625
# Epoch 100: Loss = 990.2064208984375
# Epoch 200: Loss = 723.2824096679688
# Epoch 300: Loss = 521.6023559570312
# Epoch 400: Loss = 429.23004150390625
# Epoch 500: Loss = 685.0576782226562
# Epoch 600: Loss = 792.4331665039062
# Epoch 700: Loss = 475.9099426269531
# Epoch 800: Loss = 506.0326843261719
# Epoch 900: Loss = 1514.263427734375
# lr=0.1, hidden_size=64, batch_size=256, test_loss=829.6282958984375
# Epoch 0: Loss = 125694.5625
# Epoch 100: Loss = 1042.203857421875
# Epoch 200: Loss = 805.806640625
# Epoch 300: Loss = 6669.3466796875
# Epoch 400: Loss = 930.865234375
# Epoch 500: Loss = 729.752197265625
# Epoch 600: Loss = 1482.287841796875
# Epoch 700: Loss = 525.2683715820312
# Epoch 800: Loss = 481.750244140625
# Epoch 900: Loss = 604.8123168945312
# lr=0.1, hidden_size=64, batch_size=512, test_loss=449.27947998046875
# Epoch 0: Loss = 110323.0
# Epoch 100: Loss = 948.19287109375
# Epoch 200: Loss = 1196.064697265625
# Epoch 300: Loss = 676.5111083984375
# Epoch 400: Loss = 2167.060546875
# Epoch 500: Loss = 511.949462890625
# Epoch 600: Loss = 786.8871459960938
# Epoch 700: Loss = 590.5425415039062
# Epoch 800: Loss = 1805.904296875
# Epoch 900: Loss = 434.5654296875
# lr=0.1, hidden_size=64, batch_size=1024, test_loss=752.9187622070312
# Epoch 0: Loss = 120486.7734375
# Epoch 100: Loss = 1518.6217041015625
# Epoch 200: Loss = 1519.042236328125
# Epoch 300: Loss = 3664.29345703125
# Epoch 400: Loss = 595.872314453125
# Epoch 500: Loss = 541.301025390625
# Epoch 600: Loss = 456.380126953125
# Epoch 700: Loss = 895.1397705078125
# Epoch 800: Loss = 496.97454833984375
# Epoch 900: Loss = 387.111328125
# lr=0.1, hidden_size=128, batch_size=128, test_loss=7133.24658203125
# Epoch 0: Loss = 125541.0234375
# Epoch 100: Loss = 1770.9677734375
# Epoch 200: Loss = 1262.787353515625
# Epoch 300: Loss = 1886.3031005859375
# Epoch 400: Loss = 2057.378662109375
# Epoch 500: Loss = 1374.81689453125
# Epoch 600: Loss = 3223.02685546875
# Epoch 700: Loss = 727.249755859375
# Epoch 800: Loss = 1221.5997314453125
# Epoch 900: Loss = 2711.437255859375
# lr=0.1, hidden_size=128, batch_size=256, test_loss=579.6428833007812
# Epoch 0: Loss = 115356.046875
# Epoch 100: Loss = 962.1871948242188
# Epoch 200: Loss = 168.0083465576172
# Epoch 300: Loss = 621.7747802734375
# Epoch 400: Loss = 214.5800323486328
# Epoch 500: Loss = 482.7406311035156
# Epoch 600: Loss = 315.36627197265625
# Epoch 700: Loss = 511.3519592285156
# Epoch 800: Loss = 735.0061645507812
# Epoch 900: Loss = 377.626708984375
# lr=0.1, hidden_size=128, batch_size=512, test_loss=603.6888427734375
# Epoch 0: Loss = 133249.34375
# Epoch 100: Loss = 514.9834594726562
# Epoch 200: Loss = 10375.171875
# Epoch 300: Loss = 282508.75
# Epoch 400: Loss = 580.8038330078125
# Epoch 500: Loss = 59478.6796875
# Epoch 600: Loss = 3240.380859375
# Epoch 700: Loss = 63037.48828125
# Epoch 800: Loss = 2789.487548828125
# Epoch 900: Loss = 2517.48193359375
# lr=0.1, hidden_size=128, batch_size=1024, test_loss=1036.0347900390625
# Epoch 0: Loss = 117121.4375
# Epoch 100: Loss = 1263.9921875
# Epoch 200: Loss = 12615.685546875
# Epoch 300: Loss = 1138.79443359375
# Epoch 400: Loss = 506.91668701171875
# Epoch 500: Loss = 568.2318115234375
# Epoch 600: Loss = 1091.7803955078125
# Epoch 700: Loss = 884.0889282226562
# Epoch 800: Loss = 1015.3770751953125
# Epoch 900: Loss = 501.83795166015625
# lr=0.1, hidden_size=256, batch_size=128, test_loss=746.305908203125
# Epoch 0: Loss = 108337.5234375
# Epoch 100: Loss = 541.637451171875
# Epoch 200: Loss = 554.4490966796875
# Epoch 300: Loss = 172.33682250976562
# Epoch 400: Loss = 334.921875
# Epoch 500: Loss = 281.1488342285156
# Epoch 600: Loss = 681.1555786132812
# Epoch 700: Loss = 1141.180908203125
# Epoch 800: Loss = 532.9276123046875
# Epoch 900: Loss = 213.19139099121094
# lr=0.1, hidden_size=256, batch_size=256, test_loss=120.0086669921875
# Epoch 0: Loss = 109101.7109375
# Epoch 100: Loss = 606.3738403320312
# Epoch 200: Loss = 763.2578125
# Epoch 300: Loss = 2165.695068359375
# Epoch 400: Loss = 850.7330322265625
# Epoch 500: Loss = 499.65301513671875
# Epoch 600: Loss = 2483.32861328125
# Epoch 700: Loss = 1943.795166015625
# Epoch 800: Loss = 836.3759765625
# Epoch 900: Loss = 791.3251342773438
# lr=0.1, hidden_size=256, batch_size=512, test_loss=531.4100341796875
# Epoch 0: Loss = 119648.9140625
# Epoch 100: Loss = 5269.0751953125
# Epoch 200: Loss = 33324.58203125
# Epoch 300: Loss = 26620.05078125
# Epoch 400: Loss = 27709.26953125
# Epoch 500: Loss = 39681.3671875
# Epoch 600: Loss = 2435.99267578125
# Epoch 700: Loss = 2688.130859375
# Epoch 800: Loss = 1345.1663818359375
# Epoch 900: Loss = 2510.149169921875
# lr=0.1, hidden_size=256, batch_size=1024, test_loss=6099.81787109375
# Epoch 0: Loss = 120257.40625
# Epoch 100: Loss = 129.68170166015625
# Epoch 200: Loss = 70.6305160522461
# Epoch 300: Loss = 33.262508392333984
# Epoch 400: Loss = 283.3765563964844
# Epoch 500: Loss = 12.239141464233398
# Epoch 600: Loss = 19684.36328125
# Epoch 700: Loss = 10.540614128112793
# Epoch 800: Loss = 14.292606353759766
# Epoch 900: Loss = 28.16289710998535
# lr=0.01, hidden_size=64, batch_size=128, test_loss=10.786744117736816
# Epoch 0: Loss = 122274.640625
# Epoch 100: Loss = 118.68041229248047
# Epoch 200: Loss = 33.30009460449219
# Epoch 300: Loss = 96.36222076416016
# Epoch 400: Loss = 8.119247436523438
# Epoch 500: Loss = 18.850461959838867
# Epoch 600: Loss = 5.874482154846191
# Epoch 700: Loss = 7.4267096519470215
# Epoch 800: Loss = 7.508214950561523
# Epoch 900: Loss = 4.11786413192749
# lr=0.01, hidden_size=64, batch_size=256, test_loss=243.41488647460938
# Epoch 0: Loss = 125177.859375
# Epoch 100: Loss = 288.86383056640625
# Epoch 200: Loss = 94.11428833007812
# Epoch 300: Loss = 3916.39111328125
# Epoch 400: Loss = 89.82917022705078
# Epoch 500: Loss = 2497.339111328125
# Epoch 600: Loss = 45.70350646972656
# Epoch 700: Loss = 69.1240234375
# Epoch 800: Loss = 39.84022903442383
# Epoch 900: Loss = 58.094505310058594
# lr=0.01, hidden_size=64, batch_size=512, test_loss=23.711999893188477
# Epoch 0: Loss = 140262.9375
# Epoch 100: Loss = 1846.9097900390625
# Epoch 200: Loss = 833.2542114257812
# Epoch 300: Loss = 259.33404541015625
# Epoch 400: Loss = 162.78564453125
# Epoch 500: Loss = 518.6448364257812
# Epoch 600: Loss = 201.46853637695312
# Epoch 700: Loss = 816.43310546875
# Epoch 800: Loss = 196.82928466796875
# Epoch 900: Loss = 108.26871490478516
# lr=0.01, hidden_size=64, batch_size=1024, test_loss=32.32171630859375
# Epoch 0: Loss = 116702.15625
# Epoch 100: Loss = 45.945709228515625
# Epoch 200: Loss = 17.077856063842773
# Epoch 300: Loss = 14.614760398864746
# Epoch 400: Loss = 6.906525611877441
# Epoch 500: Loss = 21.669050216674805
# Epoch 600: Loss = 3.694061279296875
# Epoch 700: Loss = 33.18357849121094
# Epoch 800: Loss = 97.83629608154297
# Epoch 900: Loss = 8.984620094299316
# lr=0.01, hidden_size=128, batch_size=128, test_loss=10.359696388244629
# Epoch 0: Loss = 117232.5390625
# Epoch 100: Loss = 228.1390838623047
# Epoch 200: Loss = 22.35015106201172
# Epoch 300: Loss = 83.33123779296875
# Epoch 400: Loss = 32.91801071166992
# Epoch 500: Loss = 53.528282165527344
# Epoch 600: Loss = 24.59095001220703
# Epoch 700: Loss = 15.973876953125
# Epoch 800: Loss = 32.33113479614258
# Epoch 900: Loss = 56.475955963134766
# lr=0.01, hidden_size=128, batch_size=256, test_loss=7.473434925079346
# Epoch 0: Loss = 108726.234375
# Epoch 100: Loss = 601.9425048828125
# Epoch 200: Loss = 85.25483703613281
# Epoch 300: Loss = 50.416770935058594
# Epoch 400: Loss = 13210.4111328125
# Epoch 500: Loss = 19.95267105102539
# Epoch 600: Loss = 19.965238571166992
# Epoch 700: Loss = 16.800512313842773
# Epoch 800: Loss = 46.044124603271484
# Epoch 900: Loss = 90.15448760986328
# lr=0.01, hidden_size=128, batch_size=512, test_loss=33.5340690612793
# Epoch 0: Loss = 128668.6640625
# Epoch 100: Loss = 39533.5390625
# Epoch 200: Loss = 236.09481811523438
# Epoch 300: Loss = 114.0329818725586
# Epoch 400: Loss = 228.2515869140625
# Epoch 500: Loss = 94.89741516113281
# Epoch 600: Loss = 51.686119079589844
# Epoch 700: Loss = 155.5535430908203
# Epoch 800: Loss = 93.14717102050781
# Epoch 900: Loss = 164.28167724609375
# lr=0.01, hidden_size=128, batch_size=1024, test_loss=30.121295928955078
# Epoch 0: Loss = 114182.84375
# Epoch 100: Loss = 377.1076965332031
# Epoch 200: Loss = 75.74244689941406
# Epoch 300: Loss = 20.123882293701172
# Epoch 400: Loss = 13.286993980407715
# Epoch 500: Loss = 34.809486389160156
# Epoch 600: Loss = 7.060915946960449
# Epoch 700: Loss = 30.30823516845703
# Epoch 800: Loss = 16.333749771118164
# Epoch 900: Loss = 26.447975158691406
# lr=0.01, hidden_size=256, batch_size=128, test_loss=16.285938262939453
# Epoch 0: Loss = 114549.71875
# Epoch 100: Loss = 31.260433197021484
# Epoch 200: Loss = 59.57804489135742
# Epoch 300: Loss = 74.6028823852539
# Epoch 400: Loss = 9.666996002197266
# Epoch 500: Loss = 183.89950561523438
# Epoch 600: Loss = 19.75937271118164
# Epoch 700: Loss = 220.40420532226562
# Epoch 800: Loss = 15.856746673583984
# Epoch 900: Loss = 42.68428421020508
# lr=0.01, hidden_size=256, batch_size=256, test_loss=162.00729370117188
# Epoch 0: Loss = 106741.546875
# Epoch 100: Loss = 504.76739501953125
# Epoch 200: Loss = 133.8069305419922
# Epoch 300: Loss = 49.48307418823242
# Epoch 400: Loss = 67.81732177734375
# Epoch 500: Loss = 14048.732421875
# Epoch 600: Loss = 12.816243171691895
# Epoch 700: Loss = 13.441400527954102
# Epoch 800: Loss = 29.31964111328125
# Epoch 900: Loss = 16.512351989746094
# lr=0.01, hidden_size=256, batch_size=512, test_loss=13.013175010681152
# Epoch 0: Loss = 110885.2890625
# Epoch 100: Loss = 3115.3173828125
# Epoch 200: Loss = 1094.30322265625
# Epoch 300: Loss = 117.447265625
# Epoch 400: Loss = 368.94329833984375
# Epoch 500: Loss = 131.89730834960938
# Epoch 600: Loss = 102.52169036865234
# Epoch 700: Loss = 523.077880859375
# Epoch 800: Loss = 155.3574981689453
# Epoch 900: Loss = 15514.611328125
# lr=0.01, hidden_size=256, batch_size=1024, test_loss=100.0810317993164
# Epoch 0: Loss = 125699.015625
# Epoch 100: Loss = 216.2428741455078
# Epoch 200: Loss = 118.51764678955078
# Epoch 300: Loss = 41.78679656982422
# Epoch 400: Loss = 59.266876220703125
# Epoch 500: Loss = 19.11032485961914
# Epoch 600: Loss = 27.7326717376709
# Epoch 700: Loss = 12.562784194946289
# Epoch 800: Loss = 9.086791038513184
# Epoch 900: Loss = 60.43683624267578
# lr=0.001, hidden_size=64, batch_size=128, test_loss=32.56121063232422
# Epoch 0: Loss = 131091.09375
# Epoch 100: Loss = 1118.8388671875
# Epoch 200: Loss = 146.39683532714844
# Epoch 300: Loss = 80.87350463867188
# Epoch 400: Loss = 38.48632049560547
# Epoch 500: Loss = 20.69802474975586
# Epoch 600: Loss = 17.07066535949707
# Epoch 700: Loss = 12.533802032470703
# Epoch 800: Loss = 12.643735885620117
# Epoch 900: Loss = 8.263689994812012
# lr=0.001, hidden_size=64, batch_size=256, test_loss=7.330721378326416
# Epoch 0: Loss = 185904.40625
# Epoch 100: Loss = 7207.6435546875
# Epoch 200: Loss = 830.3297119140625
# Epoch 300: Loss = 325.762451171875
# Epoch 400: Loss = 146.04885864257812
# Epoch 500: Loss = 74.21621704101562
# Epoch 600: Loss = 43.85673141479492
# Epoch 700: Loss = 45.843074798583984
# Epoch 800: Loss = 42.38391876220703
# Epoch 900: Loss = 24.75416374206543
# lr=0.001, hidden_size=64, batch_size=512, test_loss=18.528221130371094
# Epoch 0: Loss = 219096.84375
# Epoch 100: Loss = 31548.853515625
# Epoch 200: Loss = 4476.93994140625
# Epoch 300: Loss = 1247.27197265625
# Epoch 400: Loss = 749.1195068359375
# Epoch 500: Loss = 406.2564392089844
# Epoch 600: Loss = 215.30197143554688
# Epoch 700: Loss = 140.90219116210938
# Epoch 800: Loss = 111.14959716796875
# Epoch 900: Loss = 81.95580291748047
# lr=0.001, hidden_size=64, batch_size=1024, test_loss=57.87324142456055
# Epoch 0: Loss = 120147.4453125
# Epoch 100: Loss = 155.00357055664062
# Epoch 200: Loss = 71.53807067871094
# Epoch 300: Loss = 23.77002716064453
# Epoch 400: Loss = 92.34300231933594
# Epoch 500: Loss = 30.759876251220703
# Epoch 600: Loss = 6.921482086181641
# Epoch 700: Loss = 8.297111511230469
# Epoch 800: Loss = 148.0443115234375
# Epoch 900: Loss = 9.306217193603516
# lr=0.001, hidden_size=128, batch_size=128, test_loss=6.314957141876221
# Epoch 0: Loss = 120942.953125
# Epoch 100: Loss = 587.1749877929688
# Epoch 200: Loss = 143.07249450683594
# Epoch 300: Loss = 139.95367431640625
# Epoch 400: Loss = 40.70215606689453
# Epoch 500: Loss = 30.827611923217773
# Epoch 600: Loss = 19.99007225036621
# Epoch 700: Loss = 98.20355987548828
# Epoch 800: Loss = 86.03421020507812
# Epoch 900: Loss = 11.393153190612793
# lr=0.001, hidden_size=128, batch_size=256, test_loss=15.581777572631836
# Epoch 0: Loss = 165561.984375
# Epoch 100: Loss = 1037.2418212890625
# Epoch 200: Loss = 236.3134002685547
# Epoch 300: Loss = 118.44273376464844
# Epoch 400: Loss = 92.39080810546875
# Epoch 500: Loss = 69.68917846679688
# Epoch 600: Loss = 37.68391799926758
# Epoch 700: Loss = 41.30867004394531
# Epoch 800: Loss = 23.597000122070312
# Epoch 900: Loss = 20.356664657592773
# lr=0.001, hidden_size=128, batch_size=512, test_loss=11.888649940490723
# Epoch 0: Loss = 190814.328125
# Epoch 100: Loss = 7693.19384765625
# Epoch 200: Loss = 854.9572143554688
# Epoch 300: Loss = 301.035888671875
# Epoch 400: Loss = 147.00711059570312
# Epoch 500: Loss = 51.761573791503906
# Epoch 600: Loss = 83.43714141845703
# Epoch 700: Loss = 50.37053298950195
# Epoch 800: Loss = 19.87274932861328
# Epoch 900: Loss = 15.161703109741211
# lr=0.001, hidden_size=128, batch_size=1024, test_loss=19.383459091186523
# Epoch 0: Loss = 118228.921875
# Epoch 100: Loss = 99.44542694091797
# Epoch 200: Loss = 40.105342864990234
# Epoch 300: Loss = 50.753273010253906
# Epoch 400: Loss = 7.61313009262085
# Epoch 500: Loss = 10.301575660705566
# Epoch 600: Loss = 12.41999626159668
# Epoch 700: Loss = 6.323971271514893
# Epoch 800: Loss = 16.598785400390625
# Epoch 900: Loss = 3.426356792449951
# lr=0.001, hidden_size=256, batch_size=128, test_loss=9.576258659362793
# Epoch 0: Loss = 120697.59375
# Epoch 100: Loss = 229.65548706054688
# Epoch 200: Loss = 37.98392105102539
# Epoch 300: Loss = 67.96163177490234
# Epoch 400: Loss = 17.62373161315918
# Epoch 500: Loss = 8659.1240234375
# Epoch 600: Loss = 54.99309539794922
# Epoch 700: Loss = 16.2298526763916
# Epoch 800: Loss = 62.12547302246094
# Epoch 900: Loss = 4.044032096862793
# lr=0.001, hidden_size=256, batch_size=256, test_loss=17.33236312866211
# Epoch 0: Loss = 139683.265625
# Epoch 100: Loss = 1035.54931640625
# Epoch 200: Loss = 312.4429016113281
# Epoch 300: Loss = 218.9150848388672
# Epoch 400: Loss = 79.64620208740234
# Epoch 500: Loss = 68.3666763305664
# Epoch 600: Loss = 633.566650390625
# Epoch 700: Loss = 62.676780700683594
# Epoch 800: Loss = 62.28290939331055
# Epoch 900: Loss = 27.719039916992188
# lr=0.001, hidden_size=256, batch_size=512, test_loss=29.948333740234375
# Epoch 0: Loss = 176778.859375
# Epoch 100: Loss = 3043.93310546875
# Epoch 200: Loss = 675.1707153320312
# Epoch 300: Loss = 292.017333984375
# Epoch 400: Loss = 192.77076721191406
# Epoch 500: Loss = 88.99839782714844
# Epoch 600: Loss = 77.59231567382812
# Epoch 700: Loss = 57.23317337036133
# Epoch 800: Loss = 43.26897430419922
# Epoch 900: Loss = 42.08037567138672
# lr=0.001, hidden_size=256, batch_size=1024, test_loss=3463.09033203125
# Best hyperparameters: {'lr': 0.001, 'hidden_size': 128, 'batch_size': 128}
